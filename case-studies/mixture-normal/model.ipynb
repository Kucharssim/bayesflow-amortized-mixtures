# %%
import os, sys
# for accessing src, stan, etc.
sys.path.append(os.path.abspath(os.path.join("../..")))

import bayesflow as bf
import numpy as np
from src.models.MixtureNormal import model, unconstrain_parameters

# %%
df = model(1_000)

# %%
f=bf.diagnostics.plot_posterior_2d(unconstrain_parameters(df['prior_draws']), param_names=model.param_names["unconstrained"])

# %%
f=bf.diagnostics.plot_posterior_2d(df['prior_draws'], param_names=model.param_names["constrained"])

# %%
np.mean(df['prior_draws'], axis=0)
# Out:
# array([ 0.33773775,  0.33746696,  0.32479529, -2.11938304,  0.01445839,
#         2.15128768])
